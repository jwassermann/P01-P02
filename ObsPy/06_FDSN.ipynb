# %% [markdown]
# <div style='background-image: url("../share/images/header.svg") ; padding: 0px ; background-size: cover ; border-radius: 5px ; height: 250px'>
#     <div style="float: right ; margin: 50px ; padding: 20px ; background: rgba(255 , 255 , 255 , 0.7) ; width: 50% ; height: 150px">
#         <div style="position: relative ; top: 50% ; transform: translatey(-50%)">
#             <div style="font-size: xx-large ; font-weight: 900 ; color: rgba(0 , 0 , 0 , 0.8) ; line-height: 100%">ObsPy Tutorial</div>
#             <div style="font-size: large ; padding-top: 20px ; color: rgba(0 , 0 , 0 , 0.5)">Downloading Data</div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Seismo-Live: http://seismo-live.org
#
# ##### Authors:
# * Lion Krischer ([@krischer](https://github.com/krischer))
# * Tobias Megies ([@megies](https://github.com/megies))
# ---

# %% [markdown]
# ![](images/obspy_logo_full_524x179px.png)

# %%
# %matplotlib inline
#from __future__ import print_function
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = 12, 8

# %% [markdown]
# ObsPy has clients to directly fetch data via...
#
# - FDSN webservices (IRIS, Geofon/GFZ, USGS, NCEDC, SeisComp3 instances, ...)
# - ArcLink (EIDA, ...)
# - Earthworm
# - SeedLink (near-realtime servers)
# - NERIES/NERA/seismicportal.eu
# - NEIC
# - SeisHub (local seismological database)
#
# This introduction shows how to use the FDSN webservice client. The FDSN webservice definition is by now the default web service implemented by many data centers world wide. Clients for other protocols work similar to the FDSN client.
#
# #### Waveform Data

# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client

client = Client("IRIS")
t = UTCDateTime("2011-03-11T05:46:23")  # Tohoku Oki
st = client.get_waveforms("II", "PFO", "*", "LHZ",
                          t + 10 * 60, t + 30 * 60)
print(st)
st.plot()
# Out:
# 2 Trace(s) in Stream:
# II.PFO.00.LHZ | 2011-03-11T05:56:23.069500Z - 2011-03-11T06:16:22.069500Z | 1.0 Hz, 1200 samples
# II.PFO.10.LHZ | 2011-03-11T05:56:23.069500Z - 2011-03-11T06:16:22.069500Z | 1.0 Hz, 1200 samples

# %% [markdown]
# - again, waveform data is returned as a Stream object
# - for all custom processing workflows it does not matter if the data originates from a local file or from a web service
#
# #### Event Metadata
#
# The FDSN client can also be used to request event metadata:

# %%
client = Client('EMSC')

t = UTCDateTime("2011-03-11T05:46:23")  # Tohoku Oki
catalog = client.get_events(starttime=t - 100, endtime=t + 24 * 3600,
                            minmagnitude=7,maxmagnitude=8)
print(catalog)
catalog.plot();
# Out:
# 2 Event(s) in Catalog:
# 2011-03-11T06:25:49.800000Z | +38.220, +144.660 | 7.6  mw | manual
# 2011-03-11T06:15:41.700000Z | +36.300, +141.130 | 7.9  mw | manual

# %% [markdown]
# Requests can have a wide range of constraints (see [ObsPy Documentation](http://docs.obspy.org/packages/autogen/obspy.fdsn.client.Client.get_events.html)):
#
# - time range
# - geographical (lonlat-box, circular by distance)
# - depth range
# - magnitude range, type
# - contributing agency

# %% [markdown]
# #### Station Metadata
#
# Finally, the FDSN client can be used to request station metadata. Stations can be looked up using a wide range of constraints (see [ObsPy documentation](http://docs.obspy.org/packages/autogen/obspy.fdsn.client.Client.get_stations.html)):
#
#  * network/station code
#  * time range of operation
#  * geographical (lonlat-box, circular by distance)

# %%
client = Client("BGR")
#event = catalog[0]
#origin = event.origins[0]

# Münster
lon = 7.63
lat = 51.96

inventory = client.get_stations(longitude=lon, latitude=lat,
                                maxradius=2.5, level="response")
print(inventory)
inventory.plot()
# Out:
# Inventory created at 2023-07-24T12:46:12.789594Z
# 	Sending institution: SeisComP (BGR)
# 	Contains:
# 		Networks (10):
# 			BQ, GQ, GR, HS, KQ, LE, RN, SX, TH, YA
# 		Stations (215):
# 			BQ.BA01 (Aachen)
# 			BQ.BA02 (Stolberg)
# 			BQ.BA03 (Weisweiler)
# 			BQ.BA04 (Friesheim)
# 			BQ.BA05 (Sindorf)
# 			BQ.BA06 (Horem)
# 			BQ.BA08 (Dellbrueck)
# 			BQ.BA09 (Bensberg)
# 			BQ.BA10 (Klein Altendorf)
# 			BQ.BA11 (Dueren)
# 			BQ.BA12 (Baesweiler)
# 			BQ.BA13 (Heinsberg)
# 			BQ.BA14 (Wollersheim)
# 			BQ.BA16 (Vanikum)
# 			BQ.BA17 (Viersen)
# 			BQ.BA18 (Steinbach)
# 			BQ.BA19 (Cologne Cathedral - Basement)
# 			BQ.BA20 (Cologne Cathedral - High roof)
# 			BQ.BA26 (Cologne University)
# 			BQ.BA30 (Duerwiss)
# 			BQ.BGG (Eltz Castle)
# 			BQ.BNS (Bensberg)
# 			BQ.DREG (Dreilaegerbach)
# 			BQ.HILG (Hillesheim)
# 			BQ.HOBG (Hohbusch)
# 			BQ.JUE (Juelich)
# 			BQ.KLL (Kalltalsperre)
# 			BQ.KOE (Koeppel)
# 			BQ.LAUG (Laupendahl)
# 			BQ.NAST (Nastaetten)
# 			BQ.RODG (Dalheim Roedgen)
# 			BQ.STB (Steinbachtalsperre)
# 			GQ.R1906 (BGR Station R1906)
# 			GR.A055 (BGR Station GeneSys, Germany)
# 			GR.AHRW (GRSN Station Ahrweiler)
# 			GR.ASSE (BGE Station BGE+GRSN Station ASSE, Germany)
# 			GR.ASSE (Station Asse)
# 			GR.BBOS (BGR Station Brambostel, Germany)
# 			GR.BEDT (BGR Station Kapelle Boeddenstedt, Germany)
# 			GR.BKS1 (BGR Station Bunkerstation Klein-Sehlingen, Germany)
# 			GR.BKSB (BGR Station Bunkerstation Klein-Sehlingen, Germany)
# 			GR.BUG (GRSN Station Bochum)
# 			GR.CLNZ (GRSN Station Clenze)
# 			GR.CLZ (GRSN Station Clausthal-Zellerfeld)
# 			GR.DEEL (BGR Station Gasfeld, Germany)
# 			GR.DREG (GRSN Station Dreilaegerbach)
# 			GR.FAHL (BGR Station Forsthaus Ahlhorn, Germany)
# 			GR.FBRG (BGR Station Fassberg, Germany)
# 			GR.GOLD (GRSN Station Goldborn)
# 			GR.GOR1 (BGR Station Trebel, Germany)
# 			GR.GOR2 (BGR Station Laase, Germany)
# 			GR.GOR5 (BGR Station Dangenstorf, Germany)
# 			GR.GOR6 (BGR Station Seerau, Germany)
# 			GR.GSH (GRSN Station Grosshau)
# 			GR.GTTG (BGR Station GRSN Station Goettingen, Germany)
# 			GR.HALO (BGR Station Haberloh, Germany)
# 			GR.HAM (GRSN Station Hamburg-Harburg)
# 			GR.HAM3 (GRSN Station Hamburg-Geomatikum)
# 			GR.HAM4 (BGR Station Hamburger Sternwarte, Germany)
# 			GR.HAN0 (BGR Station GeneSys, Germany)
# 			GR.HAN0D (BGR Station GeneSys, Germany)
# 			GR.HAN1 (BGR Station GeneSys, Germany)
# 			GR.HAN2 (BGR Station GeneSys, Germany)
# 			GR.HAN3 (BGR Station GeneSys, Germany)
# 			GR.HAN3S (BGR Station GeneSys, Germany)
# 			GR.HAN4 (BGR Station GeneSys, Germany)
# 			GR.HGB8 (BGR Station Geophon-Bohrung 8, Germany) (2x)
# 			GR.HLGA1 (Helgoland radio tower)
# 			GR.HLGA2 (Helgoland AWI guest house)
# 			GR.HLGA3 (Helgoland harbour)
# 			GR.HLGB1 (Helgoland dune south)
# 			GR.HLGB2 (Helgoland dune N)
# 			GR.HLGM1 (Helgoland AWI guest house microbarom)
# 			GR.HLGM2 (Helgoland dune microbarom)
# 			GR.HUF00 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF01 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF02 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF03 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF04 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF05 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF06 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF07 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF08 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF09 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF10 (BGR Station Infrasound Hufe Experiment)
# 			GR.HUF11 (BGR Station Infrasound Hufe Experiment)
# 			GR.IGAD (GRSN Station Garlstedt)
# 			GR.IGAH1 (BGR Station Infrasound Array Garlstedt, Germany)
# 			GR.IGAH2 (BGR Station Infrasound Array Garlstedt, Germany)
# 			GR.IGAH3 (BGR Station Infrasound Array Garlstedt, Germany)
# 			GR.IGAH4 (BGR Station Infrasound Array Garlstedt, Germany)
# 			GR.KAST (GRSN Station Kahler Asten)
# 			GR.KUDEN (BGR Station Kuden, Germany)
# 			GR.KUDN (BGR Station Kuden Srfc, Germany)
# 			GR.LOCC (NED Station LOCCUM, Germany)
# 			GR.LUEB (BGR Station Luebbecke Wasserhochbehaelter, Germany) (2x)
# 			GR.MILB (BGR Station Miltenberg, Germany)
# 			GR.NRDL (GRSN Station Niedersachsen)
# 			GR.NSR5 (BGR Station Neuensothriet 5, Germany)
# 			GR.P180 (BGR Station GeneSys, Germany)
# 			GR.RAST (BGR Station Rastdorf, Germany)
# 			GR.RETH (BGR Station GRSN Station Rethem Borehole, Germany) (2x)
# 			GR.RETHO (GRSN Station RETHEM Surface)
# 			GR.SEVE (BGR Station Sevelten, Germany)
# 			GR.SYKE (BGR Station Friedhofskapelle bei Heiligenfelde, Germany)
# 			GR.TNS (GRSN Station Taunus Observatory)
# 			GR.UBBA (GRSN Station Unterbreizbach)
# 			GR.UNDO (BGR Station Undeloh, Germany)
# 			GR.WEEZ (NED Station Weetzen, Germany)
# 			GR.ZURM (BGR Station Zurm, Germany)
# 			HS.DREI (Dreieich, Taurus, Trillium compact)
# 			HS.EBSD (Ebsdorfergrund, Centaur, LE3Dlite)
# 			HS.ERNH (Ernsthofen, Taurus, Trillium compact)
# 			HS.GODD (Goddelau, Centaur, LE3Dlite)
# 			HS.GWBC (Aumenau, Centaur, LE3Dlite)
# 			HS.GWBD (Espenschied, Centaur, LE3Dlite)
# 			HS.GWBE (Wiesbaden, Centaur, LE3Dlite)
# 			HS.GWBF (Romrod, Centaur, LE3Dlite)
# 			HS.GWBO (Ockenheim, Centaur, LE3Dlite)
# 			HS.HECH (Hechtsheim, Taurus, Trillium compact)
# 			HS.MESS (Messel, Taurus, Trillium Compact)
# 			HS.RIED (Riedstadt, Centaur, Trillium compact Posthole)
# 			HS.WBA (Fuerth, Centaur, Trillium Compact)
# 			HS.WBB (Darmstadt, Centaur, LE3Dlite)
# 			HS.WBBU (Buerstadt, Centaur, LE3Dlite)
# 			HS.WBDA (Darmstadtium, Titan SMA)
# 			HS.WBED (Eschwege, Centaur, LE3Dlite)
# 			HS.WBFM (Senkenberg Museum, Centaur, Titan)
# 			HS.WBFO (Grube Fortuna, Centaur, LE3Dlite)
# 			HS.WBG (Bieber, Centaur, LE3Dlite)
# 			HS.WBNH (Neuhof, Centaur, LE3Dlite)
# 			HS.WBRD (Rasdorf, Centaur, LE3Dlite)
# 			KQ.BUESM (FTZ Buesum)
# 			KQ.QBN (Quickborn borehole)
# 			LE.ABH (Alteburg)
# 			LE.BEDO (Benndorf-Stromberg)
# 			LE.BEUR (Beuren-RLP)
# 			LE.BIW (Bindweide)
# 			LE.BODE (Bodenheim)
# 			LE.FACH (Fachingen)
# 			LE.GLOK (Glockscheid WHB)
# 			LE.IMS (Imsbach)
# 			LE.KOGO (Kobern-Gondorf)
# 			LE.LAGB (Langenfeld, Grube Bendisberg)
# 			LE.MUEZ (Muetzenich-Pruem)
# 			LE.NICK (Nickenich)
# 			LE.OCHT (Ochtendung)
# 			LE.OMED (Obermendig)
# 			LE.PYRM (Burg Pyrmont)
# 			LE.RIVT (Riveristalsperre)
# 			RN.BAHL (Ahlen) (3x)
# 			RN.BAVN (Auguste-Victoria Mine North, Haltern, Germany) (3x)
# 			RN.BAVS (Auguste-Victoria Mine South, Haltern, Germany)
# 			RN.BHOF (Ruhr-University Bochum, Hof Stiepel, Bochum, Germany)
# 			RN.BKLB (Zeche Klosterbusch, Bochum, Germany)
# 			RN.BPFI (Ruhr-University Bochum - Pfingstblume Mine)
# 			RN.BRH2 (Ruhr-University Bochum - Rheinberg 2)
# 			RN.BRH3 (Ruhr-University Bochum - Rheinberg 3)
# 			RN.BRHE (Rheinberg)
# 			RN.BSHA (Ruhr-University Bochum - Staatshochbauamt)
# 			RN.BTEZ (Ruhr-University Bochum - Technical Center)
# 			RN.BULI (Ruhr-University Bochum - State Language Institute)
# 			RN.HMES (Hamm Michael-Ende-School) (4x)
# 			RN.IBBE (Ibbenbueren (East), Germany)
# 			RN.IBBS (Ibbenbueren South)
# 			RN.WEA2 (WEA Haltern)
# 			RN.ZER1 (Prosper-Haniel 1)
# 			RN.ZER2 (Prosper-Haniel 2)
# 			RN.ZER3 (Prosper-Haniel 3)
# 			RN.ZER4 (Prosper-Haniel 4)
# 			RN.ZERL (Munitionszerlegebetrieb Huenxe, Germany)
# 			SX.WIMM (ULEIPZIG Station Wimmelburg, Germany)
# 			TH.BADSA (UJENA Station Bad Salzungen, Germany)
# 			TH.BBWF (UJENA Station Bergwerk Finstertal, Germany) (2x)
# 			TH.BONN (UJENA Station Klostergut Bonnrode, Germany)
# 			TH.CHRS (UJENA Station Christianenhaus, Germany)
# 			TH.CRUX (UJENA Station Bergwerk Schwarze Crux, Germany)
# 			TH.GLEI (UJENA Station Burg Gleichenstein, Germany)
# 			TH.LAWA (UJENA Station Ilfeld, Germany)
# 			TH.LUHNE (UJENA Station HRB Luhne-Lengefeld, Germany)
# 			TH.MEHR (UJENA Station Mehrstedt, Germany)
# 			TH.MEIN (UJENA Station Kalte Staude Meiningen, Germany)
# 			TH.MENTE (UJENA Station Menteroda, Germany)
# 			TH.MOB1 (UJENA Station Zeitzer Forst, Germany)
# 			TH.MOB6 (UJENA Station Alte Warth Moorgrund, Germany)
# 			TH.MUEN (UJENA Station Kloster Muenchenlohra, Germany)
# 			TH.NEUST (UJENA Station TS Neustadt, Germany)
# 			TH.POSS (UJENA Station Possen, Germany) (2x)
# 			TH.RUH (UJENA Station Ruhla, Germany) (2x)
# 			TH.SONN (UJENA Station Sonnenstein, Germany)
# 			TH.SPAHL (UJENA Station Spahl, Germany)
# 			TH.THWA (UJENA Station Thueringer Wald Luisenthal, Germany)
# 			TH.TIEF (UJENA Station Generalshaus Thuer. Wald, Germany)
# 			TH.VITZ (UJENA Station Vitzeroda, Germany)
# 			TH.WARTH (UJENA Station Alte Warth, Germany)
# 			YA.BEH01 (BGR Station Infrasound temp. Experiment)
# 			YA.BEH02 (BGR Station Infrasound temp. Experiment)
# 			YA.BEH03 (BGR Station Infrasound temp. Experiment)
# 			YA.BEH04 (BGR Station Infrasound temp. Experiment)
# 			YA.BEH05 (BGR Station Infrasound temp. Experiment)
# 			YA.BEH06 (BGR Station Infrasound temp. Experiment)
# 			YA.BEH07 (BGR Station Infrasound temp. Experiment)
# 		Channels (1482):
# 			BQ.BA01..DNZ, BQ.BA01..DNN, BQ.BA01..DNE, BQ.BA02..DNZ (2x),
# 			BQ.BA02..DNN (2x), BQ.BA02..DNE (2x), BQ.BA02..EHZ, BQ.BA02..EHN,
# 			BQ.BA02..EHE, BQ.BA03..DNZ, BQ.BA03..DNN, BQ.BA03..DNE,
# 			BQ.BA04..DNZ (2x), BQ.BA04..DNN (2x), BQ.BA04..DNE (2x),
# 			BQ.BA05..DNZ (2x), BQ.BA05..DNN (2x), BQ.BA05..DNE (2x),
# 			BQ.BA06..DNZ (2x), BQ.BA06..DNN (2x), BQ.BA06..DNE (2x),
# 			BQ.BA08..DNZ (2x), BQ.BA08..DNN (2x), BQ.BA08..DNE (2x),
# 			BQ.BA09..DNZ, BQ.BA09..DNN, BQ.BA09..DNE, BQ.BA10..DNZ (3x),
# 			BQ.BA10..DNN (3x), BQ.BA10..DNE (3x), BQ.BA11..DNZ (2x),
# 			BQ.BA11..DNN (2x), BQ.BA11..DNE (2x), BQ.BA12..DNZ, BQ.BA12..DNN,
# 			BQ.BA12..DNE, BQ.BA13..DNZ (2x), BQ.BA13..DNN (2x),
# 			BQ.BA13..DNE (2x), BQ.BA14..DNZ, BQ.BA14..DNN, BQ.BA14..DNE,
# 			BQ.BA16..DNZ (2x), BQ.BA16..DNN (2x), BQ.BA16..DNE (2x),
# 			BQ.BA17..DNZ, BQ.BA17..DNN, BQ.BA17..DNE, BQ.BA18..DNZ,
# 			BQ.BA18..DNN, BQ.BA18..DNE, BQ.BA19..DNZ, BQ.BA19..DNN,
# 			BQ.BA19..DNE, BQ.BA20..DNZ, BQ.BA20..DNN, BQ.BA20..DNE,
# 			BQ.BA26..DNZ, BQ.BA26..DNN, BQ.BA26..DNE, BQ.BA30..DNZ (2x),
# 			BQ.BA30..DNN, BQ.BA30..DNE (2x), BQ.BA30..SNZ, BQ.BA30..SNN,
# 			BQ.BA30..SNE, BQ.BGG..EHZ, BQ.BGG..EHN, BQ.BGG..EHE, BQ.BGG..HHZ,
# 			BQ.BGG..HHN, BQ.BGG..HHE, BQ.BNS..DNZ (2x), BQ.BNS..DNN (2x),
# 			BQ.BNS..DNE (2x), BQ.BNS..EHZ, BQ.BNS..EHN, BQ.BNS..EHE,
# 			BQ.BNS..HHZ, BQ.BNS..HHN, BQ.BNS..HHE, BQ.DREG..HHZ (2x),
# 			BQ.DREG..HHN (2x), BQ.DREG..HHE (2x), BQ.HILG..EHZ, BQ.HILG..EHN,
# 			BQ.HILG..EHE, BQ.HILG..HHZ, BQ.HILG..HHN, BQ.HILG..HHE,
# 			BQ.HOBG..EHZ, BQ.HOBG..EHN, BQ.HOBG..EHE, BQ.HOBG..HHZ (3x),
# 			BQ.HOBG..HHN (3x), BQ.HOBG..HHE (3x), BQ.JUE..EHZ (2x),
# 			BQ.JUE..EHN (2x), BQ.JUE..EHE (2x), BQ.KLL..EHZ (2x),
# 			BQ.KLL..EHN (2x), BQ.KLL..EHE (2x), BQ.KOE..EHZ, BQ.KOE..EHN,
# 			BQ.KOE..EHE, BQ.KOE..HHZ, BQ.KOE..HHN, BQ.KOE..HHE,
# 			BQ.LAUG..EHZ (2x), BQ.LAUG..EHN (2x), BQ.LAUG..EHE (2x),
# 			BQ.NAST..EHZ, BQ.NAST..EHN, BQ.NAST..EHE, BQ.NAST..HHZ,
# 			BQ.NAST..HHN, BQ.NAST..HHE, BQ.RODG..EHZ (3x), BQ.RODG..EHN (3x),
# 			BQ.RODG..EHE (3x), BQ.STB..EHZ (2x), BQ.STB..EHN (2x),
# 			BQ.STB..EHE (2x), GQ.R1906..EHZ, GQ.R1906..EHN, GQ.R1906..EHE,
# 			GR.A055..BHZ, GR.A055..BHN, GR.A055..BHE, GR.A055..HHZ,
# 			GR.A055..HHN, GR.A055..HHE, GR.A055..LHZ, GR.A055..LHN,
# 			GR.A055..LHE, GR.A055..VHZ, GR.A055..VHN, GR.A055..VHE,
# 			GR.AHRW..BHZ, GR.AHRW..BHN, GR.AHRW..BHE, GR.AHRW..HHZ,
# 			GR.AHRW..HHN, GR.AHRW..HHE, GR.AHRW..LHZ, GR.AHRW..LHN,
# 			GR.AHRW..LHE, GR.ASSE..BHZ (2x), GR.ASSE..BHN (2x),
# 			GR.ASSE..BHE (2x), GR.ASSE..HHZ (2x), GR.ASSE..HHN (2x),
# 			GR.ASSE..HHE (2x), GR.ASSE..LHZ, GR.ASSE..LHN, GR.ASSE..LHE,
# 			GR.ASSE..VHZ, GR.ASSE..VHN, GR.ASSE..VHE, GR.BBOS..EHZ,
# 			GR.BBOS..EHN, GR.BBOS..EHE, GR.BEDT..EHZ (2x), GR.BEDT..EHN (2x),
# 			GR.BEDT..EHE (2x), GR.BKS1..EHZ, GR.BKS1..EHN, GR.BKS1..EHE,
# 			GR.BKSB..BHZ, GR.BKSB..BHN, GR.BKSB..BHE, GR.BKSB..HHZ,
# 			GR.BKSB..HHN, GR.BKSB..HHE, GR.BKSB..LHZ, GR.BKSB..LHN,
# 			GR.BKSB..LHE, GR.BKSB..VHZ, GR.BKSB..VHN, GR.BKSB..VHE, GR.BUG..BHZ
# 			GR.BUG..BHN, GR.BUG..BHE, GR.BUG..HHZ, GR.BUG..HHN, GR.BUG..HHE,
# 			GR.BUG..LHZ, GR.BUG..LHN, GR.BUG..LHE, GR.CLNZ..BHZ, GR.CLNZ..BHN,
# 			GR.CLNZ..BHE, GR.CLNZ..HHZ, GR.CLNZ..HHN, GR.CLNZ..HHE,
# 			GR.CLNZ..LHZ, GR.CLNZ..LHN, GR.CLNZ..LHE, GR.CLZ..BHZ (2x),
# 			GR.CLZ..BHN (2x), GR.CLZ..BHE (2x), GR.CLZ..HHZ (2x),
# 			GR.CLZ..HHN (2x), GR.CLZ..HHE (2x), GR.CLZ..LHZ (2x),
# 			GR.CLZ..LHN (2x), GR.CLZ..LHE (2x), GR.DEEL..EHZ, GR.DEEL..EHN,
# 			GR.DEEL..EHE, GR.DREG..BHZ, GR.DREG..BHN, GR.DREG..BHE,
# 			GR.DREG..HHZ, GR.DREG..HHN, GR.DREG..HHE, GR.DREG..LHZ,
# 			GR.DREG..LHN, GR.DREG..LHE, GR.FAHL..EHZ, GR.FAHL..EHN,
# 			GR.FAHL..EHE, GR.FAHL..SHZ, GR.FAHL..SHN, GR.FAHL..SHE,
# 			GR.FBRG..BHZ, GR.FBRG..BHN, GR.FBRG..BHE, GR.FBRG..HHZ,
# 			GR.FBRG..HHN, GR.FBRG..HHE, GR.FBRG..LHZ, GR.FBRG..LHN,
# 			GR.FBRG..LHE, GR.FBRG..VHZ, GR.FBRG..VHN, GR.FBRG..VHE,
# 			GR.GOLD..BHZ, GR.GOLD..BHN, GR.GOLD..BHE, GR.GOLD..HHZ,
# 			GR.GOLD..HHN, GR.GOLD..HHE, GR.GOLD..LHZ, GR.GOLD..LHN,
# 			GR.GOLD..LHE, GR.GOR1..BHZ (2x), GR.GOR1..BHN, GR.GOR1..BHE,
# 			GR.GOR1..BH1, GR.GOR1..BH2, GR.GOR1..HHZ (2x), GR.GOR1..HHN,
# 			GR.GOR1..HHE, GR.GOR1..HH1, GR.GOR1..HH2, GR.GOR2..EHZ,
# 			GR.GOR2..EHN, GR.GOR2..EHE, GR.GOR2..SHZ, GR.GOR2..SHN,
# 			GR.GOR2..SHE, GR.GOR5..EHZ, GR.GOR5..EHN, GR.GOR5..EHE,
# 			GR.GOR5..SHZ, GR.GOR5..SHN, GR.GOR5..SHE, GR.GOR6..EHZ,
# 			GR.GOR6..EHN, GR.GOR6..EHE, GR.GOR6..SHZ, GR.GOR6..SHN,
# 			GR.GOR6..SHE, GR.GSH..BHZ, GR.GSH..BHN, GR.GSH..BHE, GR.GSH..HHZ,
# 			GR.GSH..HHN, GR.GSH..HHE, GR.GSH..LHZ, GR.GSH..LHN, GR.GSH..LHE,
# 			GR.GTTG..BHZ (2x), GR.GTTG..BHN (2x), GR.GTTG..BHE (2x),
# 			GR.GTTG..HHZ (2x), GR.GTTG..HHN (2x), GR.GTTG..HHE (2x),
# 			GR.GTTG..LHZ (2x), GR.GTTG..LHN (2x), GR.GTTG..LHE (2x),
# 			GR.HALO..EHZ, GR.HALO..EHN, GR.HALO..EHE, GR.HAM..BHZ, GR.HAM..BHN
# 			GR.HAM..BHE, GR.HAM..LHZ, GR.HAM..LHN, GR.HAM..LHE, GR.HAM3..BHZ
# 			GR.HAM3..BHN, GR.HAM3..BHE, GR.HAM3..HHZ, GR.HAM3..HHN,
# 			GR.HAM3..HHE, GR.HAM3..LHZ, GR.HAM3..LHN, GR.HAM3..LHE,
# 			GR.HAM4..BHZ, GR.HAM4..BHN, GR.HAM4..BHE, GR.HAM4..HHZ,
# 			GR.HAM4..HHN, GR.HAM4..HHE, GR.HAM4..LHZ, GR.HAM4..LHN,
# 			GR.HAM4..LHE, GR.HAM4..VHZ, GR.HAM4..VHN, GR.HAM4..VHE,
# 			GR.HAN0..DHZ (2x), GR.HAN0..DHN (2x), GR.HAN0..DHE (2x),
# 			GR.HAN0..EHZ (3x), GR.HAN0..EHN (3x), GR.HAN0..EHE (3x),
# 			GR.HAN0D..DHZ, GR.HAN0D..DHN, GR.HAN0D..DHE, GR.HAN1..DHZ (3x),
# 			GR.HAN1..DHN (3x), GR.HAN1..DHE (3x), GR.HAN1..EHZ (2x),
# 			GR.HAN1..EHN (2x), GR.HAN1..EHE (2x), GR.HAN2..DHZ (3x),
# 			GR.HAN2..DHN (3x), GR.HAN2..DHE (3x), GR.HAN2..EHZ (2x),
# 			GR.HAN2..EHN (2x), GR.HAN2..EHE (2x), GR.HAN3..DHZ (3x),
# 			GR.HAN3..DHN (3x), GR.HAN3..DHE (3x), GR.HAN3..EHZ (3x),
# 			GR.HAN3..EHN (3x), GR.HAN3..EHE (3x), GR.HAN3S..DHZ, GR.HAN3S..DHN
# 			GR.HAN3S..DHE, GR.HAN4..DHZ (5x), GR.HAN4..DHN (5x),
# 			GR.HAN4..DHE (5x), GR.HAN4..EHZ (4x), GR.HAN4..EHN (4x),
# 			GR.HAN4..EHE (4x), GR.HGB8..EHZ (2x), GR.HGB8..EH1 (2x),
# 			GR.HGB8..EH2 (2x), GR.HLGA1..HHZ, GR.HLGA1..HHN, GR.HLGA1..HHE,
# 			GR.HLGA2..HHZ, GR.HLGA2..HHN, GR.HLGA2..HHE, GR.HLGA3..HHZ,
# 			GR.HLGA3..HHN, GR.HLGA3..HHE, GR.HLGB1..HHZ, GR.HLGB1..HHN,
# 			GR.HLGB1..HHE, GR.HLGB2..HHZ, GR.HLGB2..HHN, GR.HLGB2..HHE,
# 			GR.HLGM1..BDA, GR.HLGM1..BDF, GR.HLGM2..BDA, GR.HLGM2..BDF,
# 			GR.HUF00..BDA, GR.HUF00..HDF, GR.HUF01..BDA, GR.HUF01..HDF,
# 			GR.HUF01..LKO, GR.HUF01..LWD, GR.HUF01..LWS, GR.HUF02..BDA,
# 			GR.HUF02..HDF, GR.HUF03..BDA, GR.HUF03..HDF, GR.HUF04..BDA,
# 			GR.HUF04..HDF, GR.HUF05..BDA, GR.HUF05..HDF, GR.HUF06..BDA,
# 			GR.HUF06..HDF, GR.HUF07..BDA, GR.HUF07..HDF, GR.HUF08..BDA,
# 			GR.HUF08..HDF, GR.HUF08..LKO, GR.HUF08..LWD, GR.HUF08..LWS,
# 			GR.HUF09..BDA, GR.HUF09..HDF, GR.HUF10..BDA, GR.HUF10..HDF,
# 			GR.HUF11..BDA, GR.HUF11..HDF, GR.IGAD..BHZ, GR.IGAD..BHN,
# 			GR.IGAD..BHE, GR.IGAD..HHZ, GR.IGAD..HHN, GR.IGAD..HHE,
# 			GR.IGAD..LHZ, GR.IGAD..LHN, GR.IGAD..LHE, GR.IGAH1..BDA,
# 			GR.IGAH1..BDF, GR.IGAH1..BKO, GR.IGAH1..BWD, GR.IGAH1..BWS,
# 			GR.IGAH1.00.BDF, GR.IGAH1.00.HDF, GR.IGAH1.00.LDO, GR.IGAH2..BDA,
# 			GR.IGAH2..BDF, GR.IGAH3..BDA, GR.IGAH3..BDF, GR.IGAH4..BDA,
# 			GR.IGAH4..BDF, GR.IGAH4.00.BDF, GR.IGAH4.00.HDF, GR.IGAH4.00.LDO,
# 			GR.KAST..BHZ, GR.KAST..BHN, GR.KAST..BHE, GR.KAST..HHZ,
# 			GR.KAST..HHN, GR.KAST..HHE, GR.KAST..LHZ, GR.KAST..LHN,
# 			GR.KAST..LHE, GR.KUDEN..BHZ, GR.KUDEN..BH1, GR.KUDEN..BH2,
# 			GR.KUDEN..HHZ, GR.KUDEN..HH1, GR.KUDEN..HH2, GR.KUDN..BHZ,
# 			GR.KUDN..BHN, GR.KUDN..BHE, GR.KUDN..HHZ, GR.KUDN..HHN,
# 			GR.KUDN..HHE, GR.KUDN..LHZ, GR.KUDN..LHN, GR.KUDN..LHE,
# 			GR.LOCC..BHZ, GR.LOCC..BHN, GR.LOCC..BHE, GR.LOCC..HHZ,
# 			GR.LOCC..HHN, GR.LOCC..HHE, GR.LUEB..BHZ (2x), GR.LUEB..BHN (2x),
# 			GR.LUEB..BHE (2x), GR.LUEB..HHZ (2x), GR.LUEB..HHN (2x),
# 			GR.LUEB..HHE (2x), GR.LUEB..LHZ (2x), GR.LUEB..LHN (2x),
# 			GR.LUEB..LHE (2x), GR.MILB..BHZ, GR.MILB..BHN, GR.MILB..BHE,
# 			GR.MILB..HHZ, GR.MILB..HHN, GR.MILB..HHE, GR.MILB..LHZ,
# 			GR.MILB..LHN, GR.MILB..LHE, GR.MILB..VHZ, GR.MILB..VHN,
# 			GR.MILB..VHE, GR.NRDL..BHZ (2x), GR.NRDL..BHN (2x),
# 			GR.NRDL..BHE (2x), GR.NRDL..HHZ (2x), GR.NRDL..HHN (2x),
# 			GR.NRDL..HHE (2x), GR.NRDL..LHZ, GR.NRDL..LHN, GR.NRDL..LHE,
# 			GR.NSR5..EHZ, GR.NSR5..EHN, GR.NSR5..EHE, GR.P180..DHZ,
# 			GR.P180..DHN, GR.P180..DHE, GR.RAST..EHZ, GR.RAST..EHN,
# 			GR.RAST..EHE, GR.RETH..BHZ (4x), GR.RETH..BH1 (3x),
# 			GR.RETH..BH2 (3x), GR.RETH..BHX, GR.RETH..BHY, GR.RETH..HHZ (4x),
# 			GR.RETH..HH1 (3x), GR.RETH..HH2 (3x), GR.RETH..HHX, GR.RETH..HHY,
# 			GR.RETH..LHZ (4x), GR.RETH..LH1 (3x), GR.RETH..LH2 (3x),
# 			GR.RETH..LHX, GR.RETH..LHY, GR.RETHO..BHZ, GR.RETHO..BHN,
# 			GR.RETHO..BHE, GR.RETHO..HHZ, GR.RETHO..HHN, GR.RETHO..HHE,
# 			GR.RETHO..LHZ, GR.RETHO..LHN, GR.RETHO..LHE, GR.SEVE..EHZ,
# 			GR.SEVE..EHN, GR.SEVE..EHE, GR.SEVE..SHZ, GR.SEVE..SHN,
# 			GR.SEVE..SHE, GR.SYKE..EHZ, GR.SYKE..EHN, GR.SYKE..EHE,
# 			GR.SYKE..SHZ, GR.SYKE..SHN, GR.SYKE..SHE, GR.TNS..BHZ (2x),
# 			GR.TNS..BHN (2x), GR.TNS..BHE (2x), GR.TNS..HHZ (2x),
# 			GR.TNS..HHN (2x), GR.TNS..HHE (2x), GR.TNS..LHZ (2x),
# 			GR.TNS..LHN (2x), GR.TNS..LHE (2x), GR.UBBA..BHZ (2x),
# 			GR.UBBA..BHN (2x), GR.UBBA..BHE (2x), GR.UBBA..HHZ (2x),
# 			GR.UBBA..HHN (2x), GR.UBBA..HHE (2x), GR.UNDO..EHZ, GR.UNDO..EHN,
# 			GR.UNDO..EHE, GR.WEEZ..BHZ, GR.WEEZ..BHN, GR.WEEZ..BHE,
# 			GR.WEEZ..HHZ, GR.WEEZ..HHN, GR.WEEZ..HHE, GR.ZURM..EHZ,
# 			GR.ZURM..EHN, GR.ZURM..EHE, HS.DREI..HHZ, HS.DREI..HHN,
# 			HS.DREI..HHE, HS.EBSD..HHZ (2x), HS.EBSD..HHN (2x),
# 			HS.EBSD..HHE (2x), HS.ERNH..HHZ, HS.ERNH..HHN, HS.ERNH..HHE,
# 			HS.GODD..HHZ (2x), HS.GODD..HHN (2x), HS.GODD..HHE (2x),
# 			HS.GWBC..HHZ (2x), HS.GWBC..HHN (2x), HS.GWBC..HHE (2x),
# 			HS.GWBD..HHZ (2x), HS.GWBD..HHN (2x), HS.GWBD..HHE (2x),
# 			HS.GWBE..HHZ (2x), HS.GWBE..HHN (2x), HS.GWBE..HHE (2x),
# 			HS.GWBF..HHZ (2x), HS.GWBF..HHN (2x), HS.GWBF..HHE (2x),
# 			HS.GWBO..HHZ (2x), HS.GWBO..HHN (2x), HS.GWBO..HHE (2x),
# 			HS.HECH..HHZ, HS.HECH..HHN, HS.HECH..HHE, HS.MESS..HHZ,
# 			HS.MESS..HHN, HS.MESS..HHE, HS.RIED..HHZ, HS.RIED..HHN,
# 			HS.RIED..HHE, HS.WBA..HHZ (2x), HS.WBA..HHN (2x), HS.WBA..HHE (2x)
# 			HS.WBB..HHZ (2x), HS.WBB..HHN (2x), HS.WBB..HHE (2x),
# 			HS.WBBU..HHZ, HS.WBBU..HHN, HS.WBBU..HHE, HS.WBDA..HNZ,
# 			HS.WBDA..HNX, HS.WBDA..HNY, HS.WBED..EHZ, HS.WBED..EHN,
# 			HS.WBED..EHE, HS.WBFM..HNZ, HS.WBFM..HNX, HS.WBFM..HNY,
# 			HS.WBFO..HHZ (2x), HS.WBFO..HHN (2x), HS.WBFO..HHE (2x),
# 			HS.WBG..HHZ (2x), HS.WBG..HHN (2x), HS.WBG..HHE (2x), HS.WBNH..HHZ
# 			HS.WBNH..HHN, HS.WBNH..HHE, HS.WBRD..EHZ, HS.WBRD..EHN,
# 			HS.WBRD..EHE, KQ.BUESM..HHZ, KQ.BUESM..HHN, KQ.BUESM..HHE,
# 			KQ.QBN..HHZ (2x), KQ.QBN..HHN, KQ.QBN..HHE, KQ.QBN..HH1,
# 			KQ.QBN..HH2, LE.ABH..HHZ, LE.ABH..HHN, LE.ABH..HHE, LE.BEDO..HHZ,
# 			LE.BEDO..HHN, LE.BEDO..HHE, LE.BEUR..HHZ, LE.BEUR..HHN,
# 			LE.BEUR..HHE, LE.BIW..EHZ, LE.BIW..EHN, LE.BIW..EHE,
# 			LE.BODE.00.EHZ (2x), LE.BODE.00.EHN, LE.FACH..HHZ, LE.FACH..HHN,
# 			LE.FACH..HHE, LE.GLOK..HHZ, LE.GLOK..HHN, LE.GLOK..HHE, LE.IMS..EHZ
# 			LE.IMS..EHN, LE.IMS..EHE, LE.KOGO.00.EHZ, LE.KOGO.00.EHN,
# 			LE.KOGO.00.EHE, LE.LAGB..HHZ, LE.LAGB..HHN, LE.LAGB..HHE,
# 			LE.MUEZ..HHZ, LE.MUEZ..HH1, LE.MUEZ..HH2, LE.NICK..HHZ,
# 			LE.NICK..HH1, LE.NICK..HH2, LE.OCHT..EHZ, LE.OCHT..EHN,
# 			LE.OCHT..EHE, LE.OMED..HHZ, LE.OMED..HHN, LE.OMED..HHE,
# 			LE.PYRM..HHZ, LE.PYRM..HHN, LE.PYRM..HHE, LE.RIVT..EHZ,
# 			LE.RIVT..EHN, LE.RIVT..EHE, RN.BAHL..BHZ, RN.BAHL..BHN,
# 			RN.BAHL..BHE, RN.BAHL..EHZ (2x), RN.BAHL..EHN, RN.BAHL..EHE,
# 			RN.BAHL..HHZ, RN.BAHL..HHN, RN.BAHL..HHE, RN.BAHL..LHZ (3x),
# 			RN.BAHL..LHN (2x), RN.BAHL..LHE (2x), RN.BAHL..SHZ (2x),
# 			RN.BAHL..SHN, RN.BAHL..SHE, RN.BAHL..VHZ (3x), RN.BAHL..VHN (2x),
# 			RN.BAHL..VHE (2x), RN.BAVN..BHZ, RN.BAVN..BHN, RN.BAVN..BHE,
# 			RN.BAVN..EHZ, RN.BAVN..EHN, RN.BAVN..EHE, RN.BAVN..HHZ (2x),
# 			RN.BAVN..HHN (2x), RN.BAVN..HHE (2x), RN.BAVN..LHZ (3x),
# 			RN.BAVN..LHN (3x), RN.BAVN..LHE (3x), RN.BAVN..SHZ (2x),
# 			RN.BAVN..SHN (2x), RN.BAVN..SHE (2x), RN.BAVN..VHZ (3x),
# 			RN.BAVN..VHN (3x), RN.BAVN..VHE (3x), RN.BAVS..EHZ, RN.BAVS..EHN,
# 			RN.BAVS..EHE, RN.BHOF..EHZ, RN.BHOF..LHZ, RN.BHOF..SHZ,
# 			RN.BHOF..VHZ, RN.BKLB..EHZ, RN.BKLB..LHZ, RN.BKLB..SHZ,
# 			RN.BKLB..VHZ, RN.BPFI..EHZ, RN.BPFI..EHN, RN.BPFI..EHE,
# 			RN.BPFI..LHZ, RN.BPFI..LHN, RN.BPFI..LHE, RN.BPFI..SHZ,
# 			RN.BPFI..SHN, RN.BPFI..SHE, RN.BPFI..VHZ, RN.BPFI..VHN,
# 			RN.BPFI..VHE, RN.BRH2..EHZ, RN.BRH2..EHN, RN.BRH2..EHE,
# 			RN.BRH2..LHZ, RN.BRH2..LHN, RN.BRH2..LHE, RN.BRH2..SHZ,
# 			RN.BRH2..SHN, RN.BRH2..SHE, RN.BRH2..VHZ, RN.BRH2..VHN,
# 			RN.BRH2..VHE, RN.BRH3..BHE, RN.BRH3..EHZ, RN.BRH3..EHN,
# 			RN.BRH3..EHE, RN.BRH3..LHZ, RN.BRH3..LHN, RN.BRH3..LHE,
# 			RN.BRH3..SHZ, RN.BRH3..SHN, RN.BRH3..VHZ, RN.BRH3..VHN,
# 			RN.BRH3..VHE, RN.BRHE..EHZ, RN.BRHE..EHN, RN.BRHE..EHE,
# 			RN.BRHE..LHZ, RN.BRHE..LHN, RN.BRHE..LHE, RN.BRHE..SHZ,
# 			RN.BRHE..SHN, RN.BRHE..SHE, RN.BRHE..VHZ, RN.BRHE..VHN,
# 			RN.BRHE..VHE, RN.BSHA..EHZ, RN.BSHA..LHZ, RN.BSHA..SHZ,
# 			RN.BTEZ..EHZ, RN.BTEZ..LHZ, RN.BTEZ..SHZ, RN.BULI..EHN,
# 			RN.BULI..EHE, RN.BULI..HHZ, RN.BULI..LHZ, RN.BULI..LHN,
# 			RN.BULI..LHE, RN.BULI..SHZ, RN.BULI..SHN, RN.BULI..SHE,
# 			RN.BULI..VHZ, RN.BULI..VHN, RN.BULI..VHE, RN.HMES..BHZ,
# 			RN.HMES..BHN, RN.HMES..BHE, RN.HMES..EHZ (3x), RN.HMES..EHN (3x),
# 			RN.HMES..EHE (3x), RN.HMES..HHZ, RN.HMES..HHN, RN.HMES..HHE,
# 			RN.HMES..LHZ (4x), RN.HMES..LHN (4x), RN.HMES..LHE (4x),
# 			RN.HMES..SHZ (3x), RN.HMES..SHN (3x), RN.HMES..SHE (3x),
# 			RN.HMES..VHZ, RN.HMES..VHN, RN.HMES..VHE, RN.IBBE..EHZ,
# 			RN.IBBE..EHN, RN.IBBE..EHE, RN.IBBE..LHZ, RN.IBBE..LHN,
# 			RN.IBBE..LHE, RN.IBBE..SHZ, RN.IBBE..SHN, RN.IBBE..SHE,
# 			RN.IBBE..VHZ, RN.IBBE..VHN, RN.IBBE..VHE, RN.IBBS..EHZ,
# 			RN.IBBS..EHN, RN.IBBS..EHE, RN.IBBS..LHZ, RN.IBBS..LHN,
# 			RN.IBBS..LHE, RN.IBBS..SHZ, RN.IBBS..SHN, RN.IBBS..SHE,
# 			RN.IBBS..VHZ, RN.IBBS..VHN, RN.IBBS..VHE, RN.WEA2..EHZ,
# 			RN.WEA2..EHN, RN.WEA2..EHE, RN.ZER1..EHZ, RN.ZER1..EHN,
# 			RN.ZER1..EHE, RN.ZER1..LHZ, RN.ZER1..LHN, RN.ZER1..LHE,
# 			RN.ZER1..SHZ, RN.ZER1..SHN, RN.ZER1..SHE, RN.ZER1..VHZ,
# 			RN.ZER1..VHN, RN.ZER1..VHE, RN.ZER2..EHZ, RN.ZER2..EHN,
# 			RN.ZER2..EHE, RN.ZER2..LHZ, RN.ZER2..LHN, RN.ZER2..LHE,
# 			RN.ZER2..SHZ, RN.ZER2..SHN, RN.ZER2..SHE, RN.ZER2..VHZ,
# 			RN.ZER2..VHN, RN.ZER2..VHE, RN.ZER3..EHZ, RN.ZER3..EHN,
# 			RN.ZER3..EHE, RN.ZER3..LHZ, RN.ZER3..LHN, RN.ZER3..LHE,
# 			RN.ZER3..SHZ, RN.ZER3..SHN, RN.ZER3..SHE, RN.ZER3..VHZ,
# 			RN.ZER3..VHN, RN.ZER3..VHE, RN.ZER4..EHZ, RN.ZER4..EHN,
# 			RN.ZER4..EHE, RN.ZER4..LHZ, RN.ZER4..LHN, RN.ZER4..LHE,
# 			RN.ZER4..SHZ, RN.ZER4..SHN, RN.ZER4..SHE, RN.ZER4..VHZ,
# 			RN.ZER4..VHN, RN.ZER4..VHE, RN.ZERL..EHZ, RN.ZERL..EHN,
# 			RN.ZERL..EHE, RN.ZERL..LHZ, RN.ZERL..LHN, RN.ZERL..LHE,
# 			RN.ZERL..SHZ, RN.ZERL..SHN, RN.ZERL..SHE, RN.ZERL..VHZ,
# 			RN.ZERL..VHN, RN.ZERL..VHE, SX.WIMM..BHZ (2x), SX.WIMM..BHN (2x),
# 			SX.WIMM..BHE (2x), SX.WIMM..HHZ (2x), SX.WIMM..HHN (2x),
# 			SX.WIMM..HHE (2x), SX.WIMM..LHZ (2x), SX.WIMM..LHN (2x),
# 			SX.WIMM..LHE (2x), TH.BADSA..BHZ, TH.BADSA..BHN, TH.BADSA..BHE,
# 			TH.BADSA..HHZ, TH.BADSA..HHN, TH.BADSA..HHE, TH.BADSA..LHZ,
# 			TH.BADSA..LHN, TH.BADSA..LHE, TH.BBWF..BHZ (2x), TH.BBWF..BHN (2x)
# 			TH.BBWF..BHE (2x), TH.BBWF..HHZ (2x), TH.BBWF..HHN (2x),
# 			TH.BBWF..HHE (2x), TH.BBWF..LHZ (2x), TH.BBWF..LHN (2x),
# 			TH.BBWF..LHE (2x), TH.BONN..BHZ, TH.BONN..BHN, TH.BONN..BHE,
# 			TH.BONN..HHZ, TH.BONN..HHN, TH.BONN..HHE, TH.BONN..LHZ,
# 			TH.BONN..LHN, TH.BONN..LHE, TH.CHRS..BHZ, TH.CHRS..BHN,
# 			TH.CHRS..BHE, TH.CHRS..HHZ, TH.CHRS..HHN, TH.CHRS..HHE,
# 			TH.CHRS..LHZ, TH.CHRS..LHN, TH.CHRS..LHE, TH.CRUX..BHZ (2x),
# 			TH.CRUX..BHN (2x), TH.CRUX..BHE (2x), TH.CRUX..HHZ (2x),
# 			TH.CRUX..HHN (2x), TH.CRUX..HHE (2x), TH.CRUX..LHZ (2x),
# 			TH.CRUX..LHN (2x), TH.CRUX..LHE (2x), TH.GLEI..BHZ, TH.GLEI..BHN,
# 			TH.GLEI..BHE, TH.GLEI..HHZ, TH.GLEI..HHN, TH.GLEI..HHE,
# 			TH.LAWA..BHZ, TH.LAWA..BHN, TH.LAWA..BHE, TH.LAWA..HHZ,
# 			TH.LAWA..HHN, TH.LAWA..HHE, TH.LAWA..LHZ, TH.LAWA..LHN,
# 			TH.LAWA..LHE, TH.LUHNE..BHZ, TH.LUHNE..BHN, TH.LUHNE..BHE,
# 			TH.LUHNE..HHZ, TH.LUHNE..HHN, TH.LUHNE..HHE, TH.MEHR..BHZ,
# 			TH.MEHR..BHN, TH.MEHR..BHE, TH.MEHR..HHZ, TH.MEHR..HHN,
# 			TH.MEHR..HHE, TH.MEIN..BHZ, TH.MEIN..BHN, TH.MEIN..BHE,
# 			TH.MEIN..HHZ, TH.MEIN..HHN, TH.MEIN..HHE, TH.MEIN..LHZ,
# 			TH.MEIN..LHN, TH.MEIN..LHE, TH.MENTE..BHZ, TH.MENTE..BHN,
# 			TH.MENTE..BHE, TH.MENTE..HHZ, TH.MENTE..HHN, TH.MENTE..HHE,
# 			TH.MOB1..HHZ, TH.MOB1..HHN, TH.MOB1..HHE, TH.MOB6..HHZ,
# 			TH.MOB6..HHN, TH.MOB6..HHE, TH.MUEN..BHZ, TH.MUEN..BHN,
# 			TH.MUEN..BHE, TH.MUEN..HHZ, TH.MUEN..HHN, TH.MUEN..HHE,
# 			TH.NEUST..BHZ (3x), TH.NEUST..BHN (3x), TH.NEUST..BHE (3x),
# 			TH.NEUST..HHZ (3x), TH.NEUST..HHN (3x), TH.NEUST..HHE (3x),
# 			TH.NEUST..LHZ (3x), TH.NEUST..LHN (3x), TH.NEUST..LHE (3x),
# 			TH.POSS..BHZ (2x), TH.POSS..BHN (2x), TH.POSS..BHE (2x),
# 			TH.POSS..HHZ (2x), TH.POSS..HHN (2x), TH.POSS..HHE (2x),
# 			TH.POSS..LHZ (2x), TH.POSS..LHN (2x), TH.POSS..LHE (2x),
# 			TH.RUH..BHZ, TH.RUH..BHN, TH.RUH..BHE, TH.RUH..EHZ, TH.RUH..EHN,
# 			TH.RUH..EHE, TH.RUH..HHZ, TH.RUH..HHN, TH.RUH..HHE, TH.RUH..LHZ,
# 			TH.RUH..LHN, TH.RUH..LHE, TH.SONN..BHZ (2x), TH.SONN..BHN (2x),
# 			TH.SONN..BHE (2x), TH.SONN..HHZ (2x), TH.SONN..HHN (2x),
# 			TH.SONN..HHE (2x), TH.SONN..LHZ (2x), TH.SONN..LHN (2x),
# 			TH.SONN..LHE (2x), TH.SPAHL..BHZ (2x), TH.SPAHL..BHN (2x),
# 			TH.SPAHL..BHE (2x), TH.SPAHL..HHZ (2x), TH.SPAHL..HHN (2x),
# 			TH.SPAHL..HHE (2x), TH.SPAHL..LHZ, TH.SPAHL..LHN, TH.SPAHL..LHE,
# 			TH.THWA..HHZ (3x), TH.THWA..HHN (3x), TH.THWA..HHE (3x),
# 			TH.TIEF..HHZ, TH.TIEF..HHN, TH.TIEF..HHE, TH.VITZ..BHZ (2x),
# 			TH.VITZ..BHN (2x), TH.VITZ..BHE (2x), TH.VITZ..HHZ (2x),
# 			TH.VITZ..HHN (2x), TH.VITZ..HHE (2x), TH.VITZ..LHZ (2x),
# 			TH.VITZ..LHN (2x), TH.VITZ..LHE (2x), TH.WARTH..BHZ, TH.WARTH..BHN
# 			TH.WARTH..BHE, TH.WARTH..HHZ, TH.WARTH..HHN, TH.WARTH..HHE,
# 			YA.BEH01..BDF, YA.BEH01..HDF, YA.BEH01..LDA, YA.BEH01.61.HDF,
# 			YA.BEH02..BDF, YA.BEH02..HDF, YA.BEH02..LDA, YA.BEH02.61.HDF,
# 			YA.BEH03..BDF, YA.BEH03..HDF, YA.BEH03..LDA, YA.BEH04..BDF,
# 			YA.BEH04..HDF, YA.BEH04..LDA, YA.BEH04.61.HDF, YA.BEH05..BDF,
# 			YA.BEH05..HDF, YA.BEH05..LDA, YA.BEH06..BDF, YA.BEH06..HDF,
# 			YA.BEH06..LDA, YA.BEH06.61.HDF, YA.BEH07..BDF, YA.BEH07..HDF,
# 			YA.BEH07..LDA

# %% [markdown]
# The **`level=...`** keyword is used to specify the level of detail in the requested inventory
#
# - `"network"`: only return information on networks matching the criteria
# - `"station"`: return information on all matching stations
# - `"channel"`: return information on available channels in all stations networks matching the criteria
# - `"response"`: include instrument response for all matching channels (large result data size!)

# %%
client = Client("IRIS")
inventory = client.get_stations(network="GE", station="STU",
                                level="response")
print(inventory)
# Out:
# Inventory created at 2023-07-24T12:50:22.853400Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?network=GE&station=S...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			GE
# 		Stations (4):
# 			GE.STU (VBB Station Stuttgart, Germany) (4x)
# 		Channels (39):
# 			GE.STU..BHZ (4x), GE.STU..BHN (4x), GE.STU..BHE (4x), GE.STU..HHZ,
# 			GE.STU..HHN, GE.STU..HHE, GE.STU..LHZ (4x), GE.STU..LHN (4x),
# 			GE.STU..LHE (4x), GE.STU..VHZ (4x), GE.STU..VHN (4x),
# 			GE.STU..VHE (4x)

# %%
inventory = client.get_stations(network="OE", station="DAVA",
                                level="channel")
print(inventory)
# Out:
# Inventory created at 2023-07-24T12:50:33.486200Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?network=OE&station=D...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			OE
# 		Stations (1):
# 			OE.DAVA (Damuels, Vorarlberg, Austria)
# 		Channels (14):
# 			OE.DAVA..BHZ, OE.DAVA..BHN, OE.DAVA..BHE, OE.DAVA..HHZ,
# 			OE.DAVA..HHN, OE.DAVA..HHE, OE.DAVA..LCQ, OE.DAVA..LHZ,
# 			OE.DAVA..LHN, OE.DAVA..LHE, OE.DAVA..UFC, OE.DAVA..VHZ,
# 			OE.DAVA..VHN, OE.DAVA..VHE

# %% [markdown]
# For waveform requests that include instrument correction, the appropriate instrument response information can be attached to waveforms automatically:
# (Of course, for work on large datasets, the better choice is to download all station information and avoid the internal repeated webservice requests)

# %%
t = UTCDateTime("2011-03-11T05:46:23")  # Tohoku
st = client.get_waveforms("II", "PFO", "*", "LHZ",
                          t + 10 * 60, t + 30 * 60, attach_response=True)
st.plot()

st.remove_sensitivity()
st.plot()

# %% [markdown]
# All data requested using the FDSN client can be directly saved to file using the **`filename="..."`** option. The data is then stored exactly as it is served by the data center, i.e. without first parsing by ObsPy and outputting by ObsPy.

# %%
client.get_events(starttime=t-100, endtime=t+24*3600, minmagnitude=7,
                  filename="/tmp/requested_events.xml")
client.get_stations(network="OE", station="DAVA", level="station",
                    filename="/tmp/requested_stations.xml")
client.get_waveforms("II", "PFO", "*", "LHZ", t + 10 * 60, t + 30 * 60,
                     filename="/tmp/requested_waveforms.mseed")
# !ls -lrt /tmp/requested*
client.get_events?

# %% [markdown]
# #### FDSN Client Exercise
#
# Use the FDSN client to assemble a waveform dataset for on event.
#
# - search for a large earthquake (e.g. by depth or in a region of your choice, use option **`limit=5`** to keep network traffic down)

# %%
cl = Client("IRIS")
cat = cl.get_events(limit=5,minmagnitude=7.5,starttime=UTCDateTime(2023,2,5),endtime=UTCDateTime(2023,2,8))
print(cat)
# Out:
# 2 Event(s) in Catalog:
# 2023-02-06T10:24:49.258000Z | +38.023,  +37.203 | 7.5  mww
# 2023-02-06T01:17:34.362000Z | +37.225,  +37.021 | 7.8  mww

# %% [markdown]
# - search for stations to look at waveforms for the event. stations should..
#     * be available at the time of the event
#     * have a vertical 1 Hz stream ("LHZ", to not overpower our network..)
#     * be in a narrow angular distance around the event (e.g. 90-91 degrees)
#     * adjust your search so that only a small number of stations (e.g. 3-6) match your search criteria

# %%
inv = cl.get_stations(starttime=UTCDateTime(2023,2,5),endtime=UTCDateTime(2023,2,8)
                      ,longitude=+38.023, latitude=+37.203, minradius=4,maxradius=5,level="response")
print(inv)
# Out:
# Inventory created at 2023-07-24T13:06:11.167700Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2023-02-...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (4):
# 			GE, IM, IU, SY
# 		Stations (15):
# 			GE.CSS (GEOFON/GII Station Mathiatis, Cyprus)
# 			GE.KSDI (GII Station Kfar Sold, Israel)
# 			IM.CY401 (RAF Akrotiri, Cyprus, Site CY401)
# 			IM.CY501 (temp)
# 			IM.CY601 (RAF Akrotiri, Cyprus, Site CY601)
# 			IM.CY602 (RAF Akrotiri, Cyprus, Site CY602)
# 			IM.CY603 (RAF Akrotiri, Cyprus, Site CY603)
# 			IM.CY604 (RAF Akrotiri, Cyprus, Site CY604)
# 			IM.CY605 (RAF Akrotiri, Cyprus, Site CY605)
# 			IM.CY606 (RAF Akrotiri, Cyprus, Site CY606)
# 			IU.ANTO (Ankara, Turkey)
# 			SY.ANTO (ANTO synthetic)
# 			SY.CSS (CSS synthetic)
# 			SY.KSDI (KSDI synthetic)
# 			SY.MRNI (MRNI synthetic)
# 		Channels (149):
# 			GE.CSS..BHZ, GE.CSS..BHN, GE.CSS..BHE, GE.CSS..BLZ, GE.CSS..BLN,
# 			GE.CSS..BLE, GE.CSS..HHZ, GE.CSS..HHN, GE.CSS..HHE, GE.CSS..HLZ,
# 			GE.CSS..HLN, GE.CSS..HLE, GE.CSS..LHZ, GE.CSS..LHN, GE.CSS..LHE,
# 			GE.CSS..LLZ, GE.CSS..LLN, GE.CSS..LLE, GE.CSS..SHZ, GE.CSS..SHN,
# 			GE.CSS..SHE, GE.CSS..VHZ, GE.CSS..VHN, GE.CSS..VHE, GE.KSDI..BHZ,
# 			GE.KSDI..BHN, GE.KSDI..BHE, GE.KSDI..HHZ, GE.KSDI..HHN,
# 			GE.KSDI..HHE, GE.KSDI..LHZ, GE.KSDI..LHN, GE.KSDI..LHE,
# 			GE.KSDI..SHZ, GE.KSDI..SHN, GE.KSDI..SHE, GE.KSDI..VHZ,
# 			GE.KSDI..VHN, GE.KSDI..VHE, IM.CY401..EHZ, IM.CY401..EH1,
# 			IM.CY401..EH2, IM.CY401..HHZ, IM.CY401..HH1, IM.CY401..HH2,
# 			IM.CY501..EHZ, IM.CY501..EH1, IM.CY501..EH2, IM.CY501..HHZ,
# 			IM.CY501..HH1, IM.CY501..HH2, IM.CY601..EHZ, IM.CY601..EH1,
# 			IM.CY601..EH2, IM.CY601..HHZ, IM.CY601..HH1, IM.CY601..HH2,
# 			IM.CY602..EHZ, IM.CY602..EH1, IM.CY602..EH2, IM.CY602..HHZ,
# 			IM.CY602..HH1, IM.CY602..HH2, IM.CY603..EHZ, IM.CY603..EH1,
# 			IM.CY603..EH2, IM.CY603..HHZ, IM.CY603..HH1, IM.CY603..HH2,
# 			IM.CY604..EHZ, IM.CY604..EH1, IM.CY604..EH2, IM.CY604..HHZ,
# 			IM.CY604..HH1, IM.CY604..HH2, IM.CY605..EHZ, IM.CY605..EH1,
# 			IM.CY605..EH2, IM.CY605..HHZ, IM.CY605..HH1, IM.CY605..HH2,
# 			IM.CY606..EHZ, IM.CY606..EH1, IM.CY606..EH2, IM.CY606..HHZ,
# 			IM.CY606..HH1, IM.CY606..HH2, IU.ANTO.00.BHZ, IU.ANTO.00.BH1,
# 			IU.ANTO.00.BH2, IU.ANTO.00.HHZ, IU.ANTO.00.HH1, IU.ANTO.00.HH2,
# 			IU.ANTO.00.LHZ, IU.ANTO.00.LH1, IU.ANTO.00.LH2, IU.ANTO.00.VHZ,
# 			IU.ANTO.00.VH1, IU.ANTO.00.VH2, IU.ANTO.00.VMU, IU.ANTO.00.VMV,
# 			IU.ANTO.00.VMW, IU.ANTO.10.BHZ, IU.ANTO.10.BH1, IU.ANTO.10.BH2,
# 			IU.ANTO.10.HHZ, IU.ANTO.10.HH1, IU.ANTO.10.HH2, IU.ANTO.10.LHZ,
# 			IU.ANTO.10.LH1, IU.ANTO.10.LH2, IU.ANTO.10.VHZ, IU.ANTO.10.VH1,
# 			IU.ANTO.10.VH2, IU.ANTO.10.VMU, IU.ANTO.10.VMV, IU.ANTO.10.VMW,
# 			IU.ANTO.20.HNZ, IU.ANTO.20.HN1, IU.ANTO.20.HN2, IU.ANTO.20.LNZ,
# 			IU.ANTO.20.LN1, IU.ANTO.20.LN2, IU.ANTO.30.LDO, IU.ANTO.31.LDO,
# 			SY.ANTO.S1.LXZ, SY.ANTO.S1.LXN, SY.ANTO.S1.LXE, SY.ANTO.S3.MXZ,
# 			SY.ANTO.S3.MXN, SY.ANTO.S3.MXE, SY.CSS.S1.LXZ, SY.CSS.S1.LXN,
# 			SY.CSS.S1.LXE, SY.CSS.S3.MXZ, SY.CSS.S3.MXN, SY.CSS.S3.MXE,
# 			SY.KSDI.S1.LXZ, SY.KSDI.S1.LXN, SY.KSDI.S1.LXE, SY.KSDI.S3.MXZ,
# 			SY.KSDI.S3.MXN, SY.KSDI.S3.MXE, SY.MRNI.S1.LXZ, SY.MRNI.S1.LXN,
# 			SY.MRNI.S1.LXE, SY.MRNI.S3.MXZ, SY.MRNI.S3.MXN, SY.MRNI.S3.MXE

# %% [markdown]
# - for each of these stations download data of the event, e.g. a couple of minutes before to half an hour after the event
# - put all data together in one stream (put the `get_waveforms()` call in a try/except/pass block to silently skip stations that actually have no data available)
# - print stream info, plot the raw data

# %%
cl = Client("GFZ")
start = UTCDateTime("2023-02-06T01:17:34.362000Z")-2*60
end = UTCDateTime()
st = cl.get_waveforms("GE","STU","*","BH?",starttime=UTCDateTime("2023-02-06T01:17:34.362000Z")-2*60,
                     endtime=UTCDateTime("2023-02-06T01:17:34.362000Z")+20*60)
inv = cl.get_stations(network="GE",station="STU",location="",channel="BH?",starttime=start,level="response")
print(inv)
# Out:
# Inventory created at 2023-07-24T13:16:10.321938Z
# 	Sending institution: SeisComP (GFZ)
# 	Contains:
# 		Networks (1):
# 			GE
# 		Stations (1):
# 			GE.STU (VBB Station Stuttgart, Germany)
# 		Channels (3):
# 			GE.STU..BHZ, GE.STU..BHN, GE.STU..BHE

# %% [markdown]
# - correct the instrument response for all stations and plot the corrected data

# %%
st.attach_response(inventories=inv)
st.plot()
st.remove_response()
st.plot()

# %% [markdown]
# If you have time, assemble and plot another similar dataset (e.g. like before stations at a certain distance from a big event, or use Transportable Array data for a big event, etc.)

# %% [markdown]
# ## Routing or Federator Client are also existing!!

# %%
from obspy.clients.fdsn import RoutingClient

eida = RoutingClient("eida-routing")
tr = eida.get_waveforms()
iris = RoutingClient("iris-federator")
